# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('../data files/Monthly_COVID-19_Death.csv')
df3 = pd.read_csv('../data files/AH_Cumulative_Provisional_COVID-19_Deaths.csv')
df4 = pd.read_csv('../data files/Provisional_COVID-19_death_counts.csv')
df5 = pd.read_csv('../data files/COVID-19_Weekly_Cases_and_Deaths.csv')

# %% [markdown]
# # dataset 3 (AH cumulative provisional deaths) -120 [XXXXX DROPPED XXXXX]

# %%
'''
df3.columns

df3_cleaned = df3.drop_duplicates().dropna()

df3_cleaned.describe()

print(df3_cleaned['Sex'].unique())

print(df3_cleaned['Race/Ethnicity'].unique())

print(df3_cleaned['Age group'].unique())

print(df3_cleaned['COVID-19 (U071, Multiple Cause of Death)'].unique())

print(df3_cleaned['COVID-19 (U071, Underlying Cause of Death)'].unique())

df3_cleaned.info()

# sex, race/ethnicity, age group, two COVID labels
## how to measure timeframe?

plt.scatter(df3_cleaned.loc[:, "Sex"],df3_cleaned.loc[:, "COVID-19 (U071, Multiple Cause of Death)"] )

plt.scatter(df3_cleaned.loc[:, "Sex"],df3_cleaned.loc[:, "COVID-19 (U071, Underlying Cause of Death)"] )

plt.bar(df3_cleaned.loc[:, "Race/Ethnicity"],df3_cleaned.loc[:, "COVID-19 (U071, Multiple Cause of Death)"] )

plt.scatter(df3_cleaned.loc[:, "Race/Ethnicity"],df3_cleaned.loc[:, "COVID-19 (U071, Underlying Cause of Death)"] )

plt.scatter(df3_cleaned.loc[:, "Age group"],df3_cleaned.loc[:, "COVID-19 (U071, Multiple Cause of Death)"] )

plt.scatter(df3_cleaned.loc[:, "Age group"],df3_cleaned.loc[:, "COVID-19 (U071, Underlying Cause of Death)"] )

'''
# Out:
# '\ndf3.columns\n\ndf3_cleaned = df3.drop_duplicates().dropna()\n\ndf3_cleaned.describe()\n\nprint(df3_cleaned[\'Sex\'].unique())\n\nprint(df3_cleaned[\'Race/Ethnicity\'].unique())\n\nprint(df3_cleaned[\'Age group\'].unique())\n\nprint(df3_cleaned[\'COVID-19 (U071, Multiple Cause of Death)\'].unique())\n\nprint(df3_cleaned[\'COVID-19 (U071, Underlying Cause of Death)\'].unique())\n\ndf3_cleaned.info()\n\n# sex, race/ethnicity, age group, two COVID labels\n## how to measure timeframe?\n\nplt.scatter(df3_cleaned.loc[:, "Sex"],df3_cleaned.loc[:, "COVID-19 (U071, Multiple Cause of Death)"] )\n\nplt.scatter(df3_cleaned.loc[:, "Sex"],df3_cleaned.loc[:, "COVID-19 (U071, Underlying Cause of Death)"] )\n\nplt.bar(df3_cleaned.loc[:, "Race/Ethnicity"],df3_cleaned.loc[:, "COVID-19 (U071, Multiple Cause of Death)"] )\n\nplt.scatter(df3_cleaned.loc[:, "Race/Ethnicity"],df3_cleaned.loc[:, "COVID-19 (U071, Underlying Cause of Death)"] )\n\nplt.scatter(df3_cleaned.loc[:, "Age group"],df3_cleaned.loc[:, "COVID-19 (U071, Multiple Cause of Death)"] )\n\nplt.scatter(df3_cleaned.loc[:, "Age group"],df3_cleaned.loc[:, "COVID-19 (U071, Underlying Cause of Death)"] )\n\n'

# %% [markdown]
# # Final dataset (merged) [XXXXX DROPPED XXXXX]

# %%
'''datasets = [df1_cleaned, df3_cleaned, df4_cleaned]

final_dataset = pd.concat(datasets).reset_index()
#axis = 0
final_dataset.sample(20)

final_dataset.columns

type(final_dataset)

# plt.plot(final_dataset["Races"],final_dataset["crude_rate"])

data_for_plot_one = final_dataset[['Races', 'crude_rate']].dropna()

plt.plot(data_for_plot_one["Races"], data_for_plot_one["crude_rate"],  marker='o', linestyle='-', color='b')

data_for_plot_two = final_dataset[[ 'Ages', 'crude_rate']].dropna()

plt.bar(data_for_plot_two["Ages"], data_for_plot_two["crude_rate"])






final_dataset = pd.concat(datasets).reset_index(drop=True)

final_dataset.sample(20)
 
data_for_plot = final_dataset[['Races', 'crude_rate']].dropna()

plt.bar(data_for_plot["Races"], data_for_plot["crude_rate"])


'''
# Out:
# 'datasets = [df1_cleaned, df3_cleaned, df4_cleaned]\n\nfinal_dataset = pd.concat(datasets).reset_index()\n#axis = 0\nfinal_dataset.sample(20)\n\nfinal_dataset.columns\n\ntype(final_dataset)\n\n# plt.plot(final_dataset["Races"],final_dataset["crude_rate"])\n\ndata_for_plot_one = final_dataset[[\'Races\', \'crude_rate\']].dropna()\n\nplt.plot(data_for_plot_one["Races"], data_for_plot_one["crude_rate"],  marker=\'o\', linestyle=\'-\', color=\'b\')\n\ndata_for_plot_two = final_dataset[[ \'Ages\', \'crude_rate\']].dropna()\n\nplt.bar(data_for_plot_two["Ages"], data_for_plot_two["crude_rate"])\n\n\n\n\n\n\nfinal_dataset = pd.concat(datasets).reset_index(drop=True)\n\nfinal_dataset.sample(20)\n \ndata_for_plot = final_dataset[[\'Races\', \'crude_rate\']].dropna()\n\nplt.bar(data_for_plot["Races"], data_for_plot["crude_rate"])\n\n\n'

# %% [markdown]
# # testing code space

# %%
'''# code to reproduce graph above:
x = tickets['month']
y1 = tickets['ticket_volume_received']
y2 = tickets['ticket_volume_processed']
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot()
ax.plot(x, y2, marker='o', label='Ticket Volume Received', color='red')
ax.plot(x, y1, marker='D', label='Ticket Volume Processed', color='blue')
ax.legend(loc=1)
ax.yaxis.set_major_formatter('{x:9<5.2f}')
ax.set_ylim(0,300)
ax.grid()
fig.patch.set_linewidth(5)
fig.patch.set_edgecolor('black')
plt.show();'''
# Out:
# "# code to reproduce graph above:\nx = tickets['month']\ny1 = tickets['ticket_volume_received']\ny2 = tickets['ticket_volume_processed']\nfig = plt.figure(figsize=(12, 5))\nax = fig.add_subplot()\nax.plot(x, y2, marker='o', label='Ticket Volume Received', color='red')\nax.plot(x, y1, marker='D', label='Ticket Volume Processed', color='blue')\nax.legend(loc=1)\nax.yaxis.set_major_formatter('{x:9<5.2f}')\nax.set_ylim(0,300)\nax.grid()\nfig.patch.set_linewidth(5)\nfig.patch.set_edgecolor('black')\nplt.show();"

# %% [markdown]
# # dataset 1 (death rates with doube stratification) -3278 {jurisdiction_residence, ages, races, covid_death, crude_rate}

# %%
df1.columns

df1_cleaned = df1.drop_duplicates().dropna()

print(df1_cleaned['subgroup1'].unique()) #*

print(df1_cleaned['subgroup2'].unique()) #*

# code to section out age ranges from ethnicities; subgroup1
# newdf = df[(df.origin == "JFK") & (df.carrier == "B6")]
# ages = df1_cleaned[(df1_cleaned.subgroup1 == '0-4 years')
#pd.concat([df1, df2])

ages = []
ethnicities = []



for i, row in df1_cleaned.iterrows():
    if 'years' in row['subgroup1']:
        ages.append(row.subgroup1)
        ethnicities.append(row.subgroup2)
    else:
        ethnicities.append(row.subgroup1)
        ages.append(row.subgroup2)

set(ages)
set(ethnicities)

df1_cleaned['Ages'] = ages
df1_cleaned['Races'] = ethnicities
# loop through subgroup1, find values with 'years'

df1_cleaned.sample(20)

df1_cleaned = df1_cleaned.drop(columns = ['subgroup1', 'subgroup2'])

# code to section out age ranges from ethnicities; subgroup2
df1_cleaned.sample(10)

df1_cleaned.info()

df1_cleaned.columns
# Out:
# ['Hispanic' 'Non-Hispanic Asian' 'Non-Hispanic Black' 'Non-Hispanic White'
#  'Non-Hispanic American Indian or Alaska Native'
#  'Non-Hispanic Native Hawaiian or Other Pacific Islander' '30-39 years'
#  '40-49 years' '50-64 years' '65-74 years' '75+ years' '18-29 years'
#  '12-17 years' '0-4 years' '5-11 years']
# ['30-39 years' '40-49 years' '50-64 years' '65-74 years' '75+ years'
#  '18-29 years' '12-17 years' '0-4 years' '5-11 years' 'Hispanic'
#  'Non-Hispanic Asian' 'Non-Hispanic Black' 'Non-Hispanic White'
#  'Non-Hispanic American Indian or Alaska Native'
#  'Non-Hispanic Native Hawaiian or Other Pacific Islander']
# <class 'pandas.core.frame.DataFrame'>
# Index: 3278 entries, 10656 to 73270
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   data_as_of                  3278 non-null   object
#  1   jurisdiction_residence      3278 non-null   object
#  2   data_period_start           3278 non-null   object
#  3   data_period_end             3278 non-null   object
#  4   group                       3278 non-null   object
#  5   covid_deaths                3278 non-null   float64
#  6   crude_rate                  3278 non-null   float64
#  7   conf_int_95pct_lower_crude  3278 non-null   float64
#  8   conf_int_95pct_upper_crude  3278 non-null   float64
#  9   note                        3278 non-null   object
#  10  Ages                        3278 non-null   object
#  11  Races                       3278 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 332.9+ KB
# Index(['data_as_of', 'jurisdiction_residence', 'data_period_start',
#        'data_period_end', 'group', 'covid_deaths', 'crude_rate',
#        'conf_int_95pct_lower_crude', 'conf_int_95pct_upper_crude', 'note',
#        'Ages', 'Races'],
#       dtype='object')

# %%
'''
plt.figure(figsize=(10, 6))
plt.plot(df1_cleaned['Races'], df1_cleaned['crude_rate'], marker='o', linestyle='-')
plt.xticks(rotation=90)
'''
# Out:
# "\nplt.figure(figsize=(10, 6))\nplt.plot(df1_cleaned['Races'], df1_cleaned['crude_rate'], marker='o', linestyle='-')\nplt.xticks(rotation=90)\n"

# %%
plt.figure(figsize=(10, 6))
plt.bar(df1_cleaned['Races'], df1_cleaned['crude_rate'])
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Hispanic'),
#   Text(1, 0, 'Non-Hispanic Asian'),
#   Text(2, 0, 'Non-Hispanic Black'),
#   Text(3, 0, 'Non-Hispanic White'),
#   Text(4, 0, 'Non-Hispanic American Indian or Alaska Native'),
#   Text(5, 0, 'Non-Hispanic Native Hawaiian or Other Pacific Islander')])

# %%
'''
plt.figure(figsize=(10, 6))
plt.bar(df1_cleaned['Races'], df1_cleaned['covid_deaths'])
plt.xticks(rotation=90)
'''
# Out:
# "\nplt.figure(figsize=(10, 6))\nplt.bar(df1_cleaned['Races'], df1_cleaned['covid_deaths'])\nplt.xticks(rotation=90)\n"

# %%
plt.figure(figsize=(10, 6))
plt.bar(df1_cleaned['Ages'], df1_cleaned['crude_rate'])
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, '30-39 years'),
#   Text(1, 0, '40-49 years'),
#   Text(2, 0, '50-64 years'),
#   Text(3, 0, '65-74 years'),
#   Text(4, 0, '75+ years'),
#   Text(5, 0, '18-29 years'),
#   Text(6, 0, '12-17 years'),
#   Text(7, 0, '0-4 years'),
#   Text(8, 0, '5-11 years')])

# %%
'''
plt.figure(figsize=(10, 6))
plt.bar(df1_cleaned['Ages'], df1_cleaned['covid_deaths'])
plt.xticks(rotation=90)
'''
# Out:
# "\nplt.figure(figsize=(10, 6))\nplt.bar(df1_cleaned['Ages'], df1_cleaned['covid_deaths'])\nplt.xticks(rotation=90)\n"

# %%
df1_cleaned.columns
# Out:
# Index(['data_as_of', 'jurisdiction_residence', 'data_period_start',
#        'data_period_end', 'group', 'covid_deaths', 'crude_rate',
#        'conf_int_95pct_lower_crude', 'conf_int_95pct_upper_crude', 'note',
#        'Ages', 'Races'],
#       dtype='object')

# %%
print(df1_cleaned['data_as_of'].unique())
# Out:
# ['06/13/2024']

# %%
print(df1_cleaned['data_period_start'].unique())
# Out:
# ['04/01/2020' '01/01/2022' '05/01/2020' '12/01/2020' '01/01/2021'
#  '05/01/2021' '12/01/2021' '07/01/2020' '08/01/2021' '09/01/2021'
#  '11/01/2021' '04/01/2021' '08/01/2020' '10/01/2021' '03/01/2022'
#  '12/01/2022' '02/01/2023' '01/01/2024' '03/01/2021' '02/01/2021'
#  '02/01/2022' '06/01/2020' '11/01/2020' '03/01/2020' '11/01/2022'
#  '05/01/2022' '09/01/2020' '07/01/2021' '04/01/2023' '08/01/2023'
#  '09/01/2023' '10/01/2023' '11/01/2023' '03/01/2024' '05/01/2023'
#  '06/01/2023' '04/01/2024' '06/01/2021' '10/01/2020' '06/01/2022'
#  '08/01/2022' '07/01/2022' '01/01/2023' '12/01/2023' '07/01/2023'
#  '09/01/2022' '10/01/2022' '04/01/2022' '03/01/2023' '02/01/2024'
#  '05/01/2024']

# %%
print(df1_cleaned['data_period_end'].unique())
# Out:
# ['04/30/2020' '01/31/2022' '05/31/2020' '12/31/2020' '01/31/2021'
#  '05/31/2021' '12/31/2021' '07/31/2020' '08/31/2021' '09/30/2021'
#  '11/30/2021' '04/30/2021' '08/31/2020' '10/31/2021' '03/31/2022'
#  '12/31/2022' '02/28/2023' '01/31/2024' '03/31/2021' '02/28/2021'
#  '02/28/2022' '06/30/2020' '11/30/2020' '03/31/2020' '11/30/2022'
#  '05/31/2022' '09/30/2020' '07/31/2021' '04/30/2023' '08/31/2023'
#  '09/30/2023' '10/31/2023' '11/30/2023' '03/31/2024' '05/31/2023'
#  '06/30/2023' '04/30/2024' '06/30/2021' '10/31/2020' '06/30/2022'
#  '08/31/2022' '07/31/2022' '01/31/2023' '12/31/2023' '07/31/2023'
#  '09/30/2022' '10/31/2022' '04/30/2022' '03/31/2023' '02/29/2024'
#  '05/31/2024']

# %%
sns.set_theme(style='white', rc={'figure.figsize':(10,5)})
graph = sns.barplot(data=df1_cleaned, x='Ages', y='crude_rate', hue='Races')

# %%
# for i, row in df1_cleaned.iterrows():
#     str(row)
#Doesnt seem to help; nice graph though, variables can't be changed
plt.figure()
sns.pairplot(df1_cleaned, vars=['covid_deaths', 'crude_rate'], hue = "Ages")
plt.show()
#, 'Races', 'Ages'

# %%
df1_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3278 entries, 10656 to 73270
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   data_as_of                  3278 non-null   object
#  1   jurisdiction_residence      3278 non-null   object
#  2   data_period_start           3278 non-null   object
#  3   data_period_end             3278 non-null   object
#  4   group                       3278 non-null   object
#  5   covid_deaths                3278 non-null   float64
#  6   crude_rate                  3278 non-null   float64
#  7   conf_int_95pct_lower_crude  3278 non-null   float64
#  8   conf_int_95pct_upper_crude  3278 non-null   float64
#  9   note                        3278 non-null   object
#  10  Ages                        3278 non-null   object
#  11  Races                       3278 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 332.9+ KB

# %% [markdown]
# # dataset 4 (provisional death counts) -48114 { 'jurisdiction_residence', 'year', 'month', 'COVID_deaths', ages, racess'}

# %%
df4.columns

df4_cleaned = df4.drop_duplicates()
# cannot use .dropna()

df4_cleaned.describe()

print(df4_cleaned['jurisdiction_residence'].unique())

print(df4_cleaned['group'].unique())

print(df4_cleaned['subgroup1'].unique()) #*

print(df4_cleaned['subgroup2'].unique())

df4_ages = []
df4_ethnicities = []



for i, row in df4_cleaned.iterrows():
    if 'years' in row['subgroup1']:
        df4_ages.append(row.subgroup1)
        df4_ethnicities.append(row.subgroup2)
    else:
        df4_ethnicities.append(row.subgroup1)
        df4_ages.append(row.subgroup2)

set(df4_ages)
set(df4_ethnicities)

df4_cleaned['Ages'] = df4_ages
df4_cleaned['Races'] = df4_ethnicities

df4_cleaned.sample(50)

df4_cleaned = df4_cleaned.drop(columns = ['subgroup1', 'subgroup2', 'group'])

df4_cleaned.sample(15)

print(df4_cleaned['crude_COVID_rate'].unique())

print(df4_cleaned['COVID_deaths'].unique())
# Out:
# ['United States' 'Region 1' 'Region 2' 'Region 3' 'Region 4' 'Region 5'
#  'Region 6' 'Region 7' 'Region 8' 'Region 9' 'Region 10']
# ['Sex' 'Age' 'Race' 'Race and Age']
# ['Female' 'Male' '0-4 years' '12-17 years' '18-29 years' '30-39 years'
#  '40-49 years' '5-11 years' '50-64 years' '65-74 years'
#  '75 years and over' 'Hispanic'
#  'Non-Hispanic American Indian or Alaska Native' 'Non-Hispanic Asian'
#  'Non-Hispanic Asian, Native Hawaiian or Other Pacific Islander'
#  'Non-Hispanic Black'
#  'Non-Hispanic Native Hawaiian or Other Pacific Islander'
#  'Non-Hispanic White']
# [nan '0-4 years' '12-17 years' '18-29 years' '30-39 years' '40-49 years'
#  '5-11 years' '50-64 years' '65-74 years' '75 years and over']
# [ nan  0.   1.7 ... 51.8 46.7 46.8]
# [3.000e+00 0.000e+00 2.000e+00 ... 2.399e+03 1.489e+03 7.920e+02]

# %%
print(df4_cleaned['data_as_of'].unique())
# Out:
# ['07/11/2024 12:00:00 AM']

# %%
df4_cleaned = df4_cleaned.drop(columns = ['footnote'])

# %%
df4_cleaned.columns
# Out:
# Index(['data_as_of', 'jurisdiction_residence', 'year', 'month', 'COVID_deaths',
#        'crude_COVID_rate', 'aa_COVID_rate', 'crude_COVID_rate_ann',
#        'aa_COVID_rate_ann', 'Ages', 'Races'],
#       dtype='object')

# %%
df4_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48114 entries, 0 to 48113
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   data_as_of              48114 non-null  object
#  1   jurisdiction_residence  48114 non-null  object
#  2   year                    48114 non-null  int64
#  3   month                   48114 non-null  int64
#  4   COVID_deaths            36689 non-null  float64
#  5   crude_COVID_rate        32768 non-null  float64
#  6   aa_COVID_rate           3970 non-null   float64
#  7   crude_COVID_rate_ann    32768 non-null  float64
#  8   aa_COVID_rate_ann       3970 non-null   float64
#  9   Ages                    42768 non-null  object
#  10  Races                   42768 non-null  object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 4.0+ MB

# %%
#df4_cleaned['crude_COVID_rate'] = df4_cleaned['crude_COVID_rate'].apply(str)
'''
for val in df4_cleaned['crude_COVID_rate']:
    if val[0] == 'n':
        continue
    elif val == 0.0:
        continue
    else:
        f = np.float64(val)
        df4_cleaned['crude_COVID_rate'][val] = round(f)
        '''
# Out:
# "\nfor val in df4_cleaned['crude_COVID_rate']:\n    if val[0] == 'n':\n        continue\n    elif val == 0.0:\n        continue\n    else:\n        f = np.float64(val)\n        df4_cleaned['crude_COVID_rate'][val] = round(f)\n        "

# %%
'''plt.figure(figsize=(10, 6))
plt.bar(df4_cleaned['Races'], df4_cleaned['crude_COVID_rate'])
plt.xticks(rotation=90)
'''

df4_cleaned.columns
# Out:
# Index(['data_as_of', 'jurisdiction_residence', 'year', 'month', 'COVID_deaths',
#        'crude_COVID_rate', 'aa_COVID_rate', 'crude_COVID_rate_ann',
#        'aa_COVID_rate_ann', 'Ages', 'Races'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
plt.bar(df4_cleaned['jurisdiction_residence'], df4_cleaned['COVID_deaths'])
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.bar(df4_cleaned['jurisdiction_residence'], df4_cleaned['COVID_deaths'])
#       3 plt.xticks(rotation=90)
#
# File C:\ProgramData\anaconda3\envs\my-env1\Lib\site-packages\matplotlib\pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
#    2744 def bar(
#    2745     x: float | ArrayLike,
#    (...)
#    2752     **kwargs,
#    2753 ) -> BarContainer:
# -> 2754     return gca().bar(
#    2755         x,
#    2756         height,
#    2757         width=width,
#    2758         bottom=bottom,
#    2759         align=align,
#    2760         **({"data": data} if data is not None else {}),
#    2761         **kwargs,
#    2762     )
#
# File C:\ProgramData\anaconda3\envs\my-env1\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File C:\ProgramData\anaconda3\envs\my-env1\Lib\site-packages\matplotlib\axes\_axes.py:2538, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2536     else:  # horizontal
#    2537         r.sticky_edges.x.append(l)
# -> 2538     self.add_patch(r)
#    2539     patches.append(r)
#    2541 if xerr is not None or yerr is not None:
#
# File C:\ProgramData\anaconda3\envs\my-env1\Lib\site-packages\matplotlib\axes\_base.py:2384, in _AxesBase.add_patch(self, p)
#    2382 if p.get_clip_path() is None:
#    2383     p.set_clip_path(self.patch)
# -> 2384 self._update_patch_limits(p)
#    2385 self._children.append(p)
#    2386 p._remove_method = self._children.remove
#
# File C:\ProgramData\anaconda3\envs\my-env1\Lib\site-packages\matplotlib\axes\_base.py:2426, in _AxesBase._update_patch_limits(self, patch)
#    2424         updatey = False
#    2425 trf_to_data = patch_trf - self.transData
# -> 2426 xys = trf_to_data.transform(vertices)
#    2427 self.update_datalim(xys, updatex=updatex, updatey=updatey)
#
# File C:\ProgramData\anaconda3\envs\my-env1\Lib\site-packages\matplotlib\transforms.py:1495, in Transform.transform(self, values)
#    1492 values = values.reshape((-1, self.input_dims))
#    1494 # Transform the values
# -> 1495 res = self.transform_affine(self.transform_non_affine(values))
#    1497 # Convert the result back to the shape of the input values.
#    1498 if ndim == 0:
#
# File C:\ProgramData\anaconda3\envs\my-env1\Lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\my-env1\Lib\site-packages\matplotlib\transforms.py:2409, in CompositeGenericTransform.transform_affine(self, values)
#    2406 @_api.rename_parameter("3.8", "points", "values")
#    2407 def transform_affine(self, values):
#    2408     # docstring inherited
# -> 2409     return self.get_affine().transform(values)
#
# File C:\ProgramData\anaconda3\envs\my-env1\Lib\site-packages\matplotlib\transforms.py:2436, in CompositeGenericTransform.get_affine(self)
#    2434     return self._b.get_affine()
#    2435 else:
# -> 2436     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2437                            self._a.get_affine().get_matrix()))
#
# KeyboardInterrupt:

# %%
sns.set_theme(style='white', rc={'figure.figsize':(10,5)})
graph = sns.barplot(data=df4_cleaned, x='Races', y='COVID_deaths', hue='Ages')
graph.set_xticks(graph.get_xticks())
graph.set_xticklabels(graph.get_xticklabels(), rotation=90)

# %%
sns.set_theme(style='white', rc={'figure.figsize':(10,5)})
graph = sns.barplot(data=df4_cleaned, x='Races', y='COVID_deaths', hue='jurisdiction_residence')
graph.set_xticks(graph.get_xticks())
graph.set_xticklabels(graph.get_xticklabels(), rotation=90)

# %%
df4_sex = []

for val in df4_cleaned['Races']:
    if val in ['Male', 'Female']:
        df4_sex.append(val)
    else:
        df4_sex.append(np.nan)

df4_cleaned['Sex'] = df4_sex

# %%
print(df4_cleaned['Sex'].unique())

# %%
#remove the tilde one

# %%
print(df4_cleaned['Races'].unique())

# %%
sns.set_theme(style='white', rc={'figure.figsize':(10,5)})
graph = sns.barplot(data=df4_cleaned, x='Sex', y='COVID_deaths', hue='jurisdiction_residence')
graph.set_xticks(graph.get_xticks())
graph.set_xticklabels(graph.get_xticklabels(), rotation=90)

# %%
# line grpah: xasix is months; each line is ethnicity, race, age, etc; yaxis is deatj rate

# %%
#bubble map and chloropleth map; i think just an image would work

# %%
# [2:17 PM] Andrea Bracho
# import seaborn as sns

# import pandas as pd
 
# # Create DataFrame

# df = pd.DataFrame({'category': ['A', 'B', 'C'], 'value': [10, 20, 30]})
 
# # Create barplot with bars sorted by 'value' in ascending order

# sns.barplot(x='category', y='value', data=df, order=df.sort_values('value').category)

 
# [2:17 PM] Andrea Bracho
# # Calculate mean value by category

# df_agg = df.groupby(['category'])['value'].mean().reset_index().sort_values('value')
 
# # Create barplot with bars ordered in ascending order by mean value

# sns.barplot(x='category', y='value', data=df, order=df_agg['category'])

 
# [2:27 PM] Andrea Bracho
# To create a month column a nd a year column: import pandas as pd
 
# # Assuming 'df' is your DataFrame containing the dataset

# # Convert the 'data_period_start' column to datetime format

# df['data_period_start'] = pd.to_datetime(df['data_period_start'], format='%m/%d/%Y')
 
# # Create new columns for month (full name) and year

# df['month_full'] = df['data_period_start'].dt.strftime('%B')

# df['year'] = df['data_period_start'].dt.year

 
# [2:29 PM] Andrea Bracho
# after you have the year and month column, you can create different dataframes to call them when grpahing: 
# import pandas as pd

# import seaborn as sns

# import matplotlib.pyplot as plt
 
# # Assuming 'df' is your DataFrame containing the dataset

# # Filter the DataFrame for the year 2022

# df_2022 = df[df['year'] == 2022]
 
# # Sort the age groups in ascending order

# # Make sure the 'age_group' column is of type 'category' and the categories are ordered

# age_order = sorted(df_2022['age_group'].unique(), key=lambda x: int(x.split('-')[0]))

# df_2022['age_group'] = pd.Categorical(df_2022['age_group'], categories=age_order, ordered=True)
 
# # Create the bar plot

# plt.figure(figsize=(10, 6))

# sns.barplot(x='age_group', y='crude_rate', data=df_2022, palette='viridis')
 
# # Set the title and labels

# plt.title('Crude Rate of COVID-19 by Age Group for the Year 2022')

# plt.xlabel('Age Group')

# plt.ylabel('Crude Rate')
 
# # Show the plot

# plt.show()

 
# [2:33 PM] Rakshaa M
# sns.set_theme(style='white', rc={'figure.figsize':(16,6)})

# graph = sns.barplot(data=df1_cleaned, x='year', y='crude_rate', hue='Races')

# plt.legend(title='Races', bbox_to_anchor=(1.05, 1), loc='upper left')

# plt.tight_layout()

# plt.show()
 
# [2:36 PM] Andrea Bracho
# Turn on/off spines: 
# import seaborn as sns

# import matplotlib.pyplot as plt
 
# # Your existing Seaborn theme and barplot code

# sns.set_theme(style='white', rc={'figure.figsize':(16,6)})

# graph = sns.barplot(data=df1_cleaned, x='year', y='crude_rate', hue='Races')

# plt.legend(title='Races', bbox_to_anchor=(1.05, 1), loc='upper left')
 
# # Add this line to remove the top spine

# plt.gca().spines['top'].set_visible(False)
 
# # Optionally, remove the right spine as well

# plt.gca().spines['right'].set_visible(False)
 
# # The rest of your code

# plt.tight_layout()

# plt.show()

 
# [2:42 PM] Andrea Bracho
# sns.set_theme(style='white', rc={'figure.figsize':(16,6)})

# graph = sns.barplot(data=df1_cleaned, x='year', y='crude_rate', hue='Races', errcolor=None)

# plt.legend(title='Races', bbox_to_anchor=(1.05, 1), loc='upper left')

# plt.tight_layout()

# plt.show()

 
# [2:54 PM] Andrea Bracho
# to order moths:
 
# import seaborn as sns

# import matplotlib.pyplot as plt
 
# # Assuming 'df1_cleaned' is your DataFrame and it has a 'month' column with month names

# # Define the correct order of the months

# months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
 
# # Create the line graph with months in chronological order

# sns.set_theme(style='white', rc={'figure.figsize':(16,6)})

# graph = sns.lineplot(data=df1_cleaned, x='month', y='crude_rate', hue='Races', sort=False, marker='o', order=months_order)

# plt.legend(title='Races', bbox_to_anchor=(1.05, 1), loc='upper left')

# plt.tight_layout()

# plt.show()

# %% [markdown]
# # testing code

# %%
df5.sample(50)
# Out:
#        end_of_week jurisdiction      age_group      sex  \
# 155219  2023-01-07     Region 5   5 - 11 Years     Male
# 351406  2022-02-12     Region 9        Overall     Male
# 316560  2023-02-11     Region 1  18 - 29 Years     Male
# 84604   2021-09-25    Region 10  40 - 49 Years   Female
# 378891  2021-03-27           US      75+ Years     Male
# 379888  2021-11-13           US      75+ Years   Female
# 82566   2021-05-15     Region 5  30 - 39 Years     Male
# 377084  2021-03-13           US  18 - 29 Years   Female
# 58499   2021-05-01     Region 5  50 - 64 Years     Male
# 153276  2023-06-24     Region 5  30 - 39 Years   Female
# 41111   2022-12-24     Region 4  30 - 39 Years   Female
# 316799  2023-09-30     Region 5  30 - 39 Years   Female
# 391559  2022-10-29     Region 2        Overall  Overall
# 125728  2020-07-11     Region 5  50 - 64 Years   Female
# 115699  2020-08-22     Region 7  40 - 49 Years     Male
# 348916  2020-04-25           US      75+ Years  Overall
# 348163  2021-11-13           US      75+ Years  Overall
# 320213  2023-01-28     Region 6    0 - 4 Years     Male
# 20359   2022-03-26     Region 9  50 - 64 Years   Female
# 318811  2023-05-06     Region 8  30 - 39 Years   Female
# 254251  2020-07-25     Region 7  18 - 29 Years  Overall
# 116418  2020-06-27     Region 9      75+ Years   Female
# 351070  2022-05-07     Region 8        Overall     Male
# 338038  2021-05-22     Region 4    0 - 4 Years  Overall
# 340987  2020-04-04     Region 9  30 - 39 Years  Overall
# 177927  2023-01-21     Region 5  65 - 74 Years     Male
# 127883  2020-04-18    Region 10      75+ Years   Female
# 179644  2023-09-02    Region 10      75+ Years     Male
# 11656   2022-03-19     Region 4  50 - 64 Years   Female
# 377901  2021-02-06           US  12 - 15 Years     Male
# 140193  2020-08-15     Region 1  30 - 39 Years     Male
# 337204  2021-11-13     Region 3  65 - 74 Years  Overall
# 164976  2023-10-07     Region 9  30 - 39 Years   Female
# 347756  2022-09-17           US  40 - 49 Years  Overall
# 210613  2021-09-11     Region 6  50 - 64 Years  Overall
# 389227  2023-07-08           US   5 - 11 Years   Female
# 177191  2023-01-28     Region 2  16 - 17 Years   Female
# 239509  2020-09-26     Region 9  65 - 74 Years  Overall
# 265839  2023-07-01     Region 7   5 - 11 Years  Overall
# 291514  2022-10-01     Region 8    0 - 4 Years     Male
# 361668  2020-11-07     Region 3        Overall     Male
# 201073  2022-10-01     Region 9  30 - 39 Years  Overall
# 97007   2021-11-20     Region 1  16 - 17 Years   Female
# 226539  2021-03-06     Region 5   5 - 11 Years  Overall
# 243077  2020-05-30     Region 8  18 - 29 Years  Overall
# 374454  2022-11-19           US  30 - 39 Years   Female
# 225534  2021-01-30     Region 7  18 - 29 Years  Overall
# 217183  2021-08-14     Region 5  30 - 39 Years  Overall
# 292034  2022-02-12     Region 1   5 - 11 Years   Female
# 300364  2021-09-11     Region 7  30 - 39 Years     Male
#
#        race_ethnicity_combined  case_count_suppressed  death_count_suppressed  \
# 155219               Black, NH                  118.0                     NaN
# 351406               AI/AN, NH                  914.0                    11.0
# 316560                 Overall                  515.0                     NaN
# 84604                AI/AN, NH                   88.0                     NaN
# 378891                Hispanic                  567.0                    86.0
# 379888                Hispanic                  760.0                   104.0
# 82566             Asian/PI, NH                   75.0                     NaN
# 377084               Black, NH                 4372.0                     NaN
# 58499                 Hispanic                  365.0                    16.0
# 153276               White, NH                  171.0                     NaN
# 41111                AI/AN, NH                   19.0                     NaN
# 316799                 Overall                 1923.0                     NaN
# 391559                Hispanic                 7253.0                    47.0
# 125728            Asian/PI, NH                   56.0                     NaN
# 115699                Hispanic                  139.0                     NaN
# 348916                 Overall                26428.0                  8955.0
# 348163                 Overall                25645.0                  2928.0
# 320213                 Overall                 1134.0                     NaN
# 20359                White, NH                  676.0                     NaN
# 318811                 Overall                  173.0                     NaN
# 254251               AI/AN, NH                    8.0                     NaN
# 116418               Black, NH                   53.0                    17.0
# 351070                Hispanic                  736.0                     NaN
# 338038                 Overall                 1274.0                     NaN
# 340987                 Overall                 1920.0                    14.0
# 177927               AI/AN, NH                    7.0                     NaN
# 127883                Hispanic                   11.0                     NaN
# 179644            Asian/PI, NH                    NaN                     NaN
# 11656                 Hispanic                 1595.0                     NaN
# 377901                Hispanic                 3924.0                     NaN
# 140193               AI/AN, NH                    NaN                     NaN
# 337204                 Overall                 4095.0                   190.0
# 164976               AI/AN, NH                   31.0                     NaN
# 347756                 Overall                48654.0                    29.0
# 210613               White, NH                 7470.0                   126.0
# 389227                Hispanic                  145.0                     NaN
# 177191               AI/AN, NH                    NaN                     NaN
# 239509               Black, NH                   51.0                     NaN
# 265839               White, NH                    NaN                     NaN
# 291514                 Overall                  226.0                     NaN
# 361668            Asian/PI, NH                  623.0                     NaN
# 201073               Black, NH                  190.0                     NaN
# 97007             Asian/PI, NH                    NaN                     NaN
# 226539            Asian/PI, NH                   54.0                     NaN
# 243077               AI/AN, NH                   38.0                     NaN
# 374454            Asian/PI, NH                 1333.0                     NaN
# 225534            Asian/PI, NH                   81.0                     NaN
# 217183            Asian/PI, NH                  194.0                     NaN
# 292034                 Overall                 1198.0                     NaN
# 300364                 Overall                 2660.0                     NaN
#
#         case_crude_rate_suppressed_per_100k  \
# 155219                                37.45
# 351406                               390.80
# 316560                                41.49
# 84604                                572.54
# 378891                                77.53
# 379888                                70.02
# 82566                                 41.66
# 377084                               113.94
# 58499                                131.20
# 153276                                 7.21
# 41111                                102.93
# 316799                                57.25
# 391559                               129.34
# 125728                                36.42
# 115699                               215.34
# 348916                               117.07
# 348163                               113.60
# 320213                                77.75
# 20359                                 30.14
# 318811                                20.34
# 254251                                52.80
# 116418                                59.61
# 351070                                76.09
# 338038                                33.03
# 340987                                26.23
# 177927                                82.26
# 127883                                67.70
# 179644                                  NaN
# 11656                                234.99
# 377901                               182.66
# 140193                                  NaN
# 337204                               132.17
# 164976                                91.02
# 347756                               120.67
# 210613                               177.26
# 389227                                 4.01
# 177191                                  NaN
# 239509                                22.72
# 265839                                  NaN
# 291514                                55.84
# 361668                                84.63
# 201073                                44.10
# 97007                                   NaN
# 226539                                30.47
# 243077                                74.30
# 374454                                76.12
# 225534                                91.48
# 217183                                53.09
# 292034                               220.74
# 300364                               288.46
#
#         death_crude_rate_suppressed_per_100k
# 155219                                   NaN
# 351406                                  4.70
# 316560                                   NaN
# 84604                                    NaN
# 378891                                 11.76
# 379888                                  9.58
# 82566                                    NaN
# 377084                                   NaN
# 58499                                   5.75
# 153276                                   NaN
# 41111                                    NaN
# 316799                                   NaN
# 391559                                  0.84
# 125728                                   NaN
# 115699                                   NaN
# 348916                                 39.67
# 348163                                 12.97
# 320213                                   NaN
# 20359                                    NaN
# 318811                                   NaN
# 254251                                   NaN
# 116418                                 19.12
# 351070                                   NaN
# 338038                                   NaN
# 340987                                  0.19
# 177927                                   NaN
# 127883                                   NaN
# 179644                                   NaN
# 11656                                    NaN
# 377901                                   NaN
# 140193                                   NaN
# 337204                                  6.13
# 164976                                   NaN
# 347756                                  0.07
# 210613                                  2.99
# 389227                                   NaN
# 177191                                   NaN
# 239509                                   NaN
# 265839                                   NaN
# 291514                                   NaN
# 361668                                   NaN
# 201073                                   NaN
# 97007                                    NaN
# 226539                                   NaN
# 243077                                   NaN
# 374454                                   NaN
# 225534                                   NaN
# 217183                                   NaN
# 292034                                   NaN
# 300364                                   NaN

# %%
df5.columns
# Out:
# Index(['end_of_week', 'jurisdiction', 'age_group', 'sex',
#        'race_ethnicity_combined', 'case_count_suppressed',
#        'death_count_suppressed', 'case_crude_rate_suppressed_per_100k',
#        'death_crude_rate_suppressed_per_100k'],
#       dtype='object')

# %%
df5_cleaned = df5.drop_duplicates().dropna()

# %%
df5_cleaned.columns
# Out:
# Index(['end_of_week', 'jurisdiction', 'age_group', 'sex',
#        'race_ethnicity_combined', 'case_count_suppressed',
#        'death_count_suppressed', 'case_crude_rate_suppressed_per_100k',
#        'death_crude_rate_suppressed_per_100k'],
#       dtype='object')

# %%
df5_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87714 entries, 1 to 407125
# Data columns (total 9 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   end_of_week                           87714 non-null  object
#  1   jurisdiction                          87714 non-null  object
#  2   age_group                             87714 non-null  object
#  3   sex                                   87714 non-null  object
#  4   race_ethnicity_combined               87714 non-null  object
#  5   case_count_suppressed                 87714 non-null  float64
#  6   death_count_suppressed                87714 non-null  float64
#  7   case_crude_rate_suppressed_per_100k   87714 non-null  float64
#  8   death_crude_rate_suppressed_per_100k  87714 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 6.7+ MB

# %%
print(df5_cleaned['death_crude_rate_suppressed_per_100k'].unique())
# Out:
# [ 3.03  1.79  1.66 ... 30.29 35.01 23.63]

# %%
sns.set_theme(style='white', rc={'figure.figsize':(10,5)})
graph = sns.barplot(data=df5_cleaned, x='jurisdiction', y='death_crude_rate_suppressed_per_100k', hue='sex', errorbar = None)
graph.set_xticks(graph.get_xticks())
graph.set_xticklabels(graph.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Region 4'),
#  Text(1, 0, 'Region 2'),
#  Text(2, 0, 'Region 8'),
#  Text(3, 0, 'Region 5'),
#  Text(4, 0, 'Region 10'),
#  Text(5, 0, 'Region 6'),
#  Text(6, 0, 'Region 3'),
#  Text(7, 0, 'Region 9'),
#  Text(8, 0, 'Region 1'),
#  Text(9, 0, 'Region 7'),
#  Text(10, 0, 'US')]

# %%
sns.set_theme(style='white', rc={'figure.figsize':(10,5)})
graph = sns.barplot(data=df5_cleaned, x='sex', y='death_crude_rate_suppressed_per_100k', errorbar = None)
graph.set_xticks(graph.get_xticks())
graph.set_xticklabels(graph.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Female'), Text(1, 0, 'Male'), Text(2, 0, 'Overall')]

# %%
df5_sex = []

for val in df5_cleaned['sex']:
    if val in ['Male', 'Female']:
        df5_sex.append(val)
    else:
        df5_sex.append(np.nan)

df5_cleaned['Sexes'] = df5_sex

# %%
sns.set_theme(style='white', rc={'figure.figsize':(10,5)})
graph = sns.barplot(data=df5_cleaned, x='jurisdiction', y='death_crude_rate_suppressed_per_100k', hue='Sexes', errorbar = None, palette = 'viridis')
graph.set_xticks(graph.get_xticks())
graph.set_xticklabels(graph.get_xticklabels(), rotation=90)
plt.grid(True)

# %%
#df5_cleaned.plot(kind='bar', stacked=True)

# %%
df5_cleaned.sample(20)
# Out:
#        end_of_week jurisdiction      age_group      sex  \
# 1492    2022-01-15     Region 9  40 - 49 Years     Male
# 364359  2023-02-18     Region 4        Overall     Male
# 54735   2021-10-30     Region 3      75+ Years   Female
# 278675  2021-05-01           US  40 - 49 Years  Overall
# 190971  2022-12-03     Region 4  50 - 64 Years  Overall
# 185507  2022-01-15     Region 8  50 - 64 Years  Overall
# 347716  2022-02-19           US  40 - 49 Years  Overall
# 393209  2021-03-13     Region 2        Overall  Overall
# 232988  2020-08-01     Region 6  65 - 74 Years  Overall
# 339879  2020-05-16     Region 6  30 - 39 Years  Overall
# 103855  2020-05-09     Region 2      75+ Years     Male
# 290145  2022-04-23     Region 5  65 - 74 Years   Female
# 286538  2022-01-29     Region 9  18 - 29 Years     Male
# 118344  2020-05-30     Region 3  65 - 74 Years     Male
# 356627  2021-07-24    Region 10        Overall     Male
# 258902  2023-08-26     Region 9      75+ Years  Overall
# 249264  2021-09-04     Region 9  65 - 74 Years  Overall
# 252908  2020-04-18     Region 1      75+ Years  Overall
# 309583  2020-12-26     Region 3  50 - 64 Years     Male
# 301189  2021-07-24     Region 9  18 - 29 Years     Male
#
#        race_ethnicity_combined  case_count_suppressed  death_count_suppressed  \
# 1492                 White, NH                11494.0                    24.0
# 364359               White, NH                 8658.0                   146.0
# 54735                White, NH                 1053.0                    86.0
# 278675               Black, NH                 5869.0                    56.0
# 190971               Black, NH                 1469.0                     7.0
# 185507               White, NH                11893.0                    51.0
# 347716                 Overall                82426.0                   119.0
# 393209               Black, NH                 6833.0                   132.0
# 232988                Hispanic                 1107.0                   102.0
# 339879                 Overall                 2775.0                     9.0
# 103855               White, NH                  447.0                   171.0
# 290145                 Overall                 3885.0                    15.0
# 286538                 Overall                35174.0                    13.0
# 118344               Black, NH                  107.0                    21.0
# 356627               White, NH                 2996.0                    72.0
# 258902            Asian/PI, NH                  307.0                    10.0
# 249264                Hispanic                 1088.0                    92.0
# 252908               Black, NH                  303.0                   135.0
# 309583                 Overall                11154.0                   140.0
# 301189                 Overall                 9617.0                    11.0
#
#         case_crude_rate_suppressed_per_100k  \
# 1492                                 937.43
# 364359                                43.70
# 54735                                 97.21
# 278675                               115.08
# 190971                                57.09
# 185507                               685.38
# 347716                               204.43
# 393209                               172.45
# 232988                               170.16
# 339879                                46.30
# 103855                                74.96
# 290145                               142.42
# 286538                               784.63
# 118344                                58.20
# 356627                                58.88
# 258902                                60.41
# 249264                               123.01
# 252908                               725.26
# 309583                               371.55
# 301189                               214.53
#
#         death_crude_rate_suppressed_per_100k   Sexes
# 1492                                    1.96    Male
# 364359                                  0.74    Male
# 54735                                   7.94  Female
# 278675                                  1.10     NaN
# 190971                                  0.27     NaN
# 185507                                  2.94     NaN
# 347716                                  0.30     NaN
# 393209                                  3.33     NaN
# 232988                                 15.68     NaN
# 339879                                  0.15     NaN
# 103855                                 28.68    Male
# 290145                                  0.55  Female
# 286538                                  0.29    Male
# 118344                                 11.42    Male
# 356627                                  1.42    Male
# 258902                                  1.97     NaN
# 249264                                 10.40     NaN
# 252908                                323.14     NaN
# 309583                                  4.66    Male
# 301189                                  0.25    Male
